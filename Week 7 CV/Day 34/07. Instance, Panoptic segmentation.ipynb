# %% [markdown]
# ## 1 Instance segmentation
#
# ### 1.1 What is instance segmentation?
#
# > - Instance segmentation = Semantic segmentation + distinguishing instances
#
# ### 1.2 Instance segmenters
#
# > - Mask R-CNN
#     - RoI extraction through **RoIAlign**, an improved version of RoI Pooling
#     - Mask R-CNN = Faster R-CNN + **Mask branch**
#
# > - YOLACT (You Only Look At CoefficienTs)
#     - Single stage
#     - Real-time instance segmentation network
#
# > - YolactEdge
#     - Extend YOLACT to video
#
# ## 2. Panoptic segmentation
#
# ### 2.1 What is panoptic segmentation?
#
# > - Semantic segmentation vs. panoptic segmentation
#     - Stuff + Things / Stuff + Instances of Things
#
# ### 2.2 UPSNet
#
# > - Semantic & Instance head -> Panoptic head -> Panoptic logits
#
# ### 2.3 VPSNet
#
# > - 1) Align reference features onto the target feature map (Fusion at pixel level)
# > - 2) Track module associated different object instances (Track at instance level)
# > - 3) Fused-and-tracked modules are trained to synergize each other
#
# ## 3. Landmark localization
#
# ### 3.1 What is landmark localization?
#
# > - Landmark localization (= ketpoint estimation) : Predicting the coordinates of keypoints
#
# ### 3.2 Coordinate regression vs. Heatmap classification
#
# > - Coordinate regression : usually inaccurate and biased
# > - **Heatmap classification** : better performance but high computational cost
#
# > - Landmark location to Gaussian heatmap
#     - $ G_\sigma (x, y) = \exp{ \left( -\frac{(x - x_c)^2 + (y - y_c)^2}{2 \sigma^2} \right) }$
#
# ### 3.3 Hourglass network
#
# > - **Stacked hourglass modules** allow for repeated bottom-up and top-down inference that refines the output of the previous hourglass module
#
# ### 3.4 Extensions
#
# > - DensePose
#     - All pixels -> 3D surface of the human body
#
# > - **UV map** is a flattened representation of 3D geometry
# > - Also, UV map is invariant to motion (i.e., canonical coordinate)
#
# > - DensePose R-CNN = Faster R-CNN + **3D surface regression branch**
#
# > - RetinaFace
#     - RetinaFace = FPN + **Multi-task branches**
#         - classification, bouding box, 5 point regression, mesh regression
#
# > - Extension pattern
#     - FPN + **Target-task branches**
#
# ## 4. Detecting objects as keypoints
#
# ### 4.1 CornerNet & CenterNet
#
# > - CornerNet
#     - Bounding box = {Top-left, Bottom-right} corners
#
# > - CenterNet
#     - 1) Bounding box = {Top-left, Bottom-right, **Center**} points
#     - 2) Bounding box = {**Width**, **Height** Center} points
